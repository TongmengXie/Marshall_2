# %%
# !pip install --upgrade pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable

# %%
import pandas as pd

data = pd.read_stata('../ori_data/Patent_data.dta',convert_categoricals=False)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 data = pd.read_stata('../ori_data/Patent_data.dta',convert_categoricals=False)
#       4 data
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/stata.py:2090, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2087     return reader
#    2089 with reader:
# -> 2090     return reader.read()
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/stata.py:1784, in StataReader.read(self, nrows, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals)
#    1781     if type(typ) is int:
#    1782         data[col] = data[col].apply(self._decode, convert_dtype=True)
# ...

# %%
reader = pd.read_stata('../ori_data/Patent_data.dta', chunksize=1000)
for chunk in reader:
    print(chunk.head())
# Out:
#    v1 publicationnumber ipccodemain                       title  \
# 0   1        US1039988A    H04Q3/00      CONTROLLING APPARATUS.
# 1   2         US904673A                             NOZZLE-TIP.
# 2   3         US801025A              ATTACHMENT FOR GAS-STOVES.
# 3   4         US869781A    A47K5/12             PNEUMATIC PUMP.
# 4   5         US744148A    A63H1/04   SELF-WINDING TOP-SPINNER.
#
#   publicationdate patentoffice applicationnumber       inventorsnames  \
# 0      01/10/1912           US       US1039988DA      MOLINA EDWARD C
# 1      24/11/1908           US     US1905267270A    BIDEKER WILLIAM E
# 2      03/10/1905           US     US1904236928A  LEIBENGLICK SCHIMON
# 3      29/10/1907           US     US1906300047A      HOLDEN DANIEL L
# 4      17/11/1903           US     US1902119054A      WILSON ROBERT J
#
#   inventorsbvdidnumbers                 applicantsnames  \
# 0                     .  AMERICAN TELEPHONE & TELEGRAPH
# ...
